# %%
import sys
sys.path.append('../')
import numpy as np
import pickle
import matplotlib.pyplot as plt
from helper import *

# %%
bpfile = open('../results/gaussian_bptt','rb')
bp_dict = pickle.load(bpfile)
bpfile.close()

lcfile = open('../results/gaussian_local','rb')
lc_dict = pickle.load(lcfile)
lcfile.close()

# %%
plt.plot(bp_dict['loss_list'])
plt.plot(lc_dict['loss_list'])
plt.show()

# %%
N = 200
T = 100
hidden_N = 200
bptt_depth = 100

inputs = create_inputs(N, T+1, T, sigma=15)
y_mini = np.zeros((N, bptt_depth))
y_mini[:,:bptt_depth] = inputs[:,:bptt_depth]

# %%
plt.imshow(bp_dict['output_rep'][-1])
plt.colorbar()
plt.clim(0.003,0.01)
plt.show()

plt.imshow(y_mini)
plt.clim(0.003,0.01)
plt.colorbar()
plt.show()

plt.imshow(bp_dict['hidden_rep'][-1])
plt.colorbar()
plt.show()

# %%
plt.imshow(lc_dict['output_rep'][-1])
plt.colorbar()
plt.clim(0.003,0.01)
plt.show()

plt.imshow(y_mini)
plt.clim(0.003,0.01)
plt.colorbar()
plt.show()

plt.imshow(lc_dict['hidden_rep'][-1])
plt.colorbar()
plt.show()
